# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
RDM=pd.read_excel('exp3_RelianceDataMart.xlsx')
RDM
# Out:
#     Rice_Bag_Weight
# 0             24.50
# 1             24.70
# 2             25.60
# 3             25.00
# 4             24.70
# 5             23.30
# 6             23.30
# 7             24.00
# 8             25.10
# 9             24.30
# 10            23.30
# 11            24.10
# 12            24.10
# 13            24.20
# 14            25.20
# 15            24.90
# 16            24.70
# 17            24.10
# 18            25.00
# 19            24.70
# 20            24.90
# 21            25.00
# 22            24.00
# 23            23.98
# 24            24.30
# 25            24.20
# 26            24.56
# 27            24.50
# 28            24.70

# %%
print(RDM.mean())
# Out:
# Rice_Bag_Weight    24.446207
# dtype: float64

# %%
RDM.describe()
# Out:
#        Rice_Bag_Weight
# count        29.000000
# mean         24.446207
# std           0.569463
# min          23.300000
# 25%          24.100000
# 50%          24.500000
# 75%          24.900000
# max          25.600000

# %%
one_sample_result=stats.ttest_1samp(RDM,24.446)
print(one_sample_result)
# Out:
# TtestResult(statistic=array([0.00195653]), pvalue=array([0.99845279]), df=array([28]))

# %%
pre_post_score=pd.read_excel('exp3_Pre_Post_Score.xlsx')
pre_post_score

# pre_post_score=pd.read_excel('exp3_Pre_Post_Score.xlsx')
# pre_post_score
# Out:
#    t-Test: Paired Two Sample for Means  Unnamed: 1  Unnamed: 2
# 0                                  NaN         NaN         NaN
# 1                                  NaN  Variable 1  Variable 2
# 2                                 Mean        18.4       20.45
# 3                             Variance    9.936842   16.471053
# 4                         Observations          20          20
# 5                  Pearson Correlation    0.717477         NaN
# 6         Hypothesized Mean Difference           0         NaN
# 7                                   df          19         NaN
# 8                               t Stat   -3.231253         NaN
# 9                     P(T<=t) one-tail    0.002197         NaN
# 10                 t Critical one-tail    1.729133         NaN
# 11                    P(T<=t) two-tail    0.004395         NaN
# 12                 t Critical two-tail    2.093024         NaN

# %%
pre_post_score = pre_post_score.ffill(axis=1)
print(pre_post_score)
# Out:
#    t-Test: Paired Two Sample for Means  Unnamed: 1  Unnamed: 2
# 0                                  NaN  Variable 1  Variable 2
# 1                                  NaN  Variable 1  Variable 2
# 2                                 Mean        18.4       20.45
# 3                             Variance    9.936842   16.471053
# 4                         Observations          20          20
# 5                  Pearson Correlation    0.717477    0.717477
# 6         Hypothesized Mean Difference           0           0
# 7                                   df          19          19
# 8                               t Stat   -3.231253   -3.231253
# 9                     P(T<=t) one-tail    0.002197    0.002197
# 10                 t Critical one-tail    1.729133    1.729133
# 11                    P(T<=t) two-tail    0.004395    0.004395
# 12                 t Critical two-tail    2.093024    2.093024

# %%
two_sample_result=stats.ttest_rel(pre_post_score ["Unnamed: 1"], pre_post_score ["Unnamed: 2"])
two_sample_result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-0b2a6acb671a> in <cell line: 1>()
# ----> 1 two_sample_result=stats.ttest_rel(pre_post_score ["Unnamed: 1"], pre_post_score ["Unnamed: 2"])
#       2 two_sample_result
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_axis_nan_policy.py in axis_nan_policy_wrapper(***failed resolving arguments***)
#     521                 if sentinel:
#     522                     samples = _remove_sentinel(samples, paired, sentinel)
# --> 523                 res = hypotest_fun_out(*samples, **kwds)
#     524                 res = result_to_tuple(res)
#     525                 res = _add_reduced_axes(res, reduced_axes, keepdims)
#
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py in ttest_rel(a, b, axis, nan_policy, alternative)
#    7795     df = n - 1
#    7796
# ...

# %%
Crocin_Data_ST=pd.read_excel('/content/Crocin_Data_ST.xlsx')
Crocin_Data_ST
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-c0c0878b71d9> in <cell line: 1>()
# ----> 1 Crocin_Data_ST=pd.read_excel('/content/Crocin_Data_ST.xlsx')
#       2 Crocin_Data_ST
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %%
two_sample_result1=stats.ttest_rel(Crocin_Data_ST["Before_Crocin"],Crocin_Data_ST["After_Crocin"])
print(two_sample_result1)
